# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=380381e2b26896999f1b2e8ebae9cdfc&q=manicore'

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city_name,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | asyut
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 1 | yuancheng
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | burnie
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | chifeng
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | kromy
# Processing Record 20 of Set 1 | saint anthony
# Processing Record 21 of Set 1 | palmer
# Processing Record 22 of Set 1 | viedma
# Processing Record 23 of Set 1 | sioux lookout
# Processing Record 24 of Set 1 | zhitikara
# City not found. Skipping...
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | basco
# Processing Record 27 of Set 1 | nenjiang
# Processing Record 28 of Set 1 | hasaki
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | novobataysk
# Processing Record 31 of Set 1 | sao joao nepomuceno
# Processing Record 32 of Set 1 | los llanos de aridane
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | vreed en hoop
# City not found. Skipping...
# Processing Record 36 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 1 | senanga
# Processing Record 38 of Set 1 | laguna
# Processing Record 39 of Set 1 | kutum
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 1 | stykkisholmur
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | pinawa
# Processing Record 49 of Set 1 | buraydah
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 2 | guerrero negro
# Processing Record 5 of Set 2 | angostura
# Processing Record 6 of Set 2 | carballo
# Processing Record 7 of Set 2 | gainesville
# Processing Record 8 of Set 2 | nuuk
# Processing Record 9 of Set 2 | lensk
# Processing Record 10 of Set 2 | shorapani
# Processing Record 11 of Set 2 | lahaina
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | drayton valley
# Processing Record 14 of Set 2 | san rafael
# Processing Record 15 of Set 2 | ahipara
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | port keats
# Processing Record 19 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 2 | san quintin
# Processing Record 21 of Set 2 | dukat
# Processing Record 22 of Set 2 | mazamitla
# Processing Record 23 of Set 2 | taoudenni
# Processing Record 24 of Set 2 | bandarbeyla
# Processing Record 25 of Set 2 | kijang
# Processing Record 26 of Set 2 | zilupe
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | dombarovskiy
# Processing Record 34 of Set 2 | manono
# Processing Record 35 of Set 2 | belyy yar
# Processing Record 36 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | isla del bosque
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | talnakh
# Processing Record 42 of Set 2 | hami
# Processing Record 43 of Set 2 | dicabisagan
# Processing Record 44 of Set 2 | beringovskiy
# Processing Record 45 of Set 2 | cockburn town
# Processing Record 46 of Set 2 | flic en flac
# Processing Record 47 of Set 2 | alice springs
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | cabedelo
# Processing Record 50 of Set 2 | bonthe
# Processing Record 1 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 2 of Set 3 | taksimo
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | hede
# Processing Record 5 of Set 3 | kupang
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | pasni
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | pozo colorado
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | port macquarie
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | rosarito
# Processing Record 15 of Set 3 | acapulco
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | mahajanga
# Processing Record 19 of Set 3 | catalao
# Processing Record 20 of Set 3 | harper
# Processing Record 21 of Set 3 | ipilan
# Processing Record 22 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 3 | bogalusa
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | cherskiy
# Processing Record 26 of Set 3 | cordoba
# Processing Record 27 of Set 3 | san fernando
# Processing Record 28 of Set 3 | darhan
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | nouadhibou
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | havre-saint-pierre
# Processing Record 33 of Set 3 | shingu
# Processing Record 34 of Set 3 | winneba
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | isangel
# Processing Record 37 of Set 3 | kiruna
# Processing Record 38 of Set 3 | amazar
# Processing Record 39 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | bam
# Processing Record 43 of Set 3 | rabat
# Processing Record 44 of Set 3 | dibaya
# City not found. Skipping...
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | sabang
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | itarema
# Processing Record 49 of Set 3 | san patricio
# Processing Record 50 of Set 3 | palia kalan
# Processing Record 1 of Set 4 | morondava
# Processing Record 2 of Set 4 | rio branco
# Processing Record 3 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 4 | balkhash
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | ponta delgada
# Processing Record 7 of Set 4 | scicli
# Processing Record 8 of Set 4 | tir pol
# City not found. Skipping...
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | abashiri
# Processing Record 11 of Set 4 | quatre cocos
# Processing Record 12 of Set 4 | ponte de sor
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | grindavik
# Processing Record 15 of Set 4 | luwuk
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | awbari
# Processing Record 18 of Set 4 | hermanus
# Processing Record 19 of Set 4 | kaeo
# Processing Record 20 of Set 4 | rincon
# Processing Record 21 of Set 4 | urucara
# Processing Record 22 of Set 4 | ilulissat
# Processing Record 23 of Set 4 | nelson bay
# Processing Record 24 of Set 4 | gualeguaychu
# Processing Record 25 of Set 4 | aktau
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | skjervoy
# Processing Record 29 of Set 4 | aklavik
# Processing Record 30 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | santa maria
# Processing Record 33 of Set 4 | waipawa
# Processing Record 34 of Set 4 | clyde river
# Processing Record 35 of Set 4 | kumluca
# Processing Record 36 of Set 4 | port moresby
# Processing Record 37 of Set 4 | shaoyang
# Processing Record 38 of Set 4 | sucila
# Processing Record 39 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 4 | ixtapa
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | aguachica
# Processing Record 43 of Set 4 | sao joao da barra
# Processing Record 44 of Set 4 | finschhafen
# Processing Record 45 of Set 4 | mount gambier
# Processing Record 46 of Set 4 | yendi
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | jiaojiang
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | taguatinga
# Processing Record 1 of Set 5 | tarakan
# Processing Record 2 of Set 5 | tam ky
# Processing Record 3 of Set 5 | tiksi
# Processing Record 4 of Set 5 | hithadhoo
# Processing Record 5 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 5 | kavaratti
# Processing Record 7 of Set 5 | dunedin
# Processing Record 8 of Set 5 | bandundu
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | wajima
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 5 | areia branca
# Processing Record 15 of Set 5 | fort nelson
# Processing Record 16 of Set 5 | pisco
# Processing Record 17 of Set 5 | san cristobal
# Processing Record 18 of Set 5 | castro
# Processing Record 19 of Set 5 | la ronge
# Processing Record 20 of Set 5 | amapa
# Processing Record 21 of Set 5 | liverpool
# Processing Record 22 of Set 5 | rio grande
# Processing Record 23 of Set 5 | east wenatchee bench
# Processing Record 24 of Set 5 | buala
# Processing Record 25 of Set 5 | lewiston
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | kulhudhuffushi
# Processing Record 28 of Set 5 | we
# City not found. Skipping...
# Processing Record 29 of Set 5 | jinchang
# Processing Record 30 of Set 5 | mucurapo
# Processing Record 31 of Set 5 | comarapa
# Processing Record 32 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 5 | saint-joseph
# Processing Record 34 of Set 5 | nemuro
# Processing Record 35 of Set 5 | westport
# Processing Record 36 of Set 5 | comodoro rivadavia
# Processing Record 37 of Set 5 | susehri
# Processing Record 38 of Set 5 | west fargo
# Processing Record 39 of Set 5 | cayenne
# Processing Record 40 of Set 5 | dawei
# Processing Record 41 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 5 | jalu
# Processing Record 43 of Set 5 | irtyshskiy
# Processing Record 44 of Set 5 | bethel
# Processing Record 45 of Set 5 | gizo
# Processing Record 46 of Set 5 | bireun
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 49 of Set 5 | muros
# Processing Record 50 of Set 5 | kieta
# Processing Record 1 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 6 | aban
# Processing Record 3 of Set 6 | lieksa
# Processing Record 4 of Set 6 | puerto escondido
# Processing Record 5 of Set 6 | ponta do sol
# Processing Record 6 of Set 6 | nicoya
# Processing Record 7 of Set 6 | yerbogachen
# Processing Record 8 of Set 6 | mitsamiouli
# Processing Record 9 of Set 6 | hulyaypole
# Processing Record 10 of Set 6 | mangrol
# Processing Record 11 of Set 6 | palembang
# Processing Record 12 of Set 6 | the pas
# Processing Record 13 of Set 6 | sambava
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | mehamn
# Processing Record 16 of Set 6 | alihe
# Processing Record 17 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 6 | villa carlos paz
# Processing Record 19 of Set 6 | rio gallegos
# Processing Record 20 of Set 6 | swidwin
# Processing Record 21 of Set 6 | umm lajj
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | flores
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | kontagora
# Processing Record 26 of Set 6 | sokolovskoye
# Processing Record 27 of Set 6 | provideniya
# Processing Record 28 of Set 6 | vineland
# Processing Record 29 of Set 6 | vanderhoof
# Processing Record 30 of Set 6 | mumford
# Processing Record 31 of Set 6 | saiha
# Processing Record 32 of Set 6 | manokwari
# Processing Record 33 of Set 6 | husavik
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | salalah
# Processing Record 37 of Set 6 | sorong
# Processing Record 38 of Set 6 | novyy urgal
# Processing Record 39 of Set 6 | lasa
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | summerland
# Processing Record 42 of Set 6 | tautira
# Processing Record 43 of Set 6 | presidencia roque saenz pena
# Processing Record 44 of Set 6 | harrison
# Processing Record 45 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 6 | verkhoyansk
# Processing Record 47 of Set 6 | matamoros
# Processing Record 48 of Set 6 | shangrao
# Processing Record 49 of Set 6 | marawi
# Processing Record 50 of Set 6 | tsiroanomandidy
# Processing Record 1 of Set 7 | weligama
# Processing Record 2 of Set 7 | menongue
# Processing Record 3 of Set 7 | caravelas
# Processing Record 4 of Set 7 | villarrica
# Processing Record 5 of Set 7 | batagay
# Processing Record 6 of Set 7 | kautokeino
# Processing Record 7 of Set 7 | iquitos
# Processing Record 8 of Set 7 | meghraj
# Processing Record 9 of Set 7 | grand gaube
# Processing Record 10 of Set 7 | turukhansk
# Processing Record 11 of Set 7 | eureka
# Processing Record 12 of Set 7 | saint-pierre
# Processing Record 13 of Set 7 | asfi
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | alta floresta
# Processing Record 16 of Set 7 | iskateley
# Processing Record 17 of Set 7 | vila
# Processing Record 18 of Set 7 | point pedro
# Processing Record 19 of Set 7 | sorland
# Processing Record 20 of Set 7 | oktyabrskoye
# Processing Record 21 of Set 7 | shambu
# Processing Record 22 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 7 | peleduy
# Processing Record 24 of Set 7 | longyearbyen
# Processing Record 25 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 7 | pangnirtung
# Processing Record 27 of Set 7 | vostok
# Processing Record 28 of Set 7 | storm lake
# Processing Record 29 of Set 7 | batagay-alyta
# Processing Record 30 of Set 7 | gwadar
# Processing Record 31 of Set 7 | margate
# Processing Record 32 of Set 7 | khandyga
# Processing Record 33 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 7 | koumac
# Processing Record 35 of Set 7 | kostomuksha
# Processing Record 36 of Set 7 | neepawa
# Processing Record 37 of Set 7 | otradnoye
# Processing Record 38 of Set 7 | luganville
# Processing Record 39 of Set 7 | sitka
# Processing Record 40 of Set 7 | benguela
# Processing Record 41 of Set 7 | kloulklubed
# Processing Record 42 of Set 7 | lazaro cardenas
# Processing Record 43 of Set 7 | kununurra
# Processing Record 44 of Set 7 | erzin
# Processing Record 45 of Set 7 | pervomayskoye
# Processing Record 46 of Set 7 | bolshaya irba
# City not found. Skipping...
# Processing Record 47 of Set 7 | puerto del rosario
# Processing Record 48 of Set 7 | yulara
# Processing Record 49 of Set 7 | zhigansk
# Processing Record 50 of Set 7 | berlevag
# Processing Record 1 of Set 8 | tekkali
# Processing Record 2 of Set 8 | leo
# Processing Record 3 of Set 8 | elk city
# Processing Record 4 of Set 8 | tamiahua
# Processing Record 5 of Set 8 | sal rei
# Processing Record 6 of Set 8 | nanortalik
# Processing Record 7 of Set 8 | komsomolskiy
# Processing Record 8 of Set 8 | buchanan
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | coquimbo
# Processing Record 11 of Set 8 | sundsvall
# Processing Record 12 of Set 8 | airai
# Processing Record 13 of Set 8 | mount isa
# Processing Record 14 of Set 8 | jacqueville
# Processing Record 15 of Set 8 | mar del plata
# Processing Record 16 of Set 8 | carutapera
# Processing Record 17 of Set 8 | hailey
# Processing Record 18 of Set 8 | adelaide
# Processing Record 19 of Set 8 | zyryanka
# Processing Record 20 of Set 8 | lumberton
# Processing Record 21 of Set 8 | vila franca do campo
# Processing Record 22 of Set 8 | napanee
# Processing Record 23 of Set 8 | utete
# Processing Record 24 of Set 8 | codrington
# Processing Record 25 of Set 8 | nueva concepcion
# Processing Record 26 of Set 8 | hervey bay
# Processing Record 27 of Set 8 | north bend
# Processing Record 28 of Set 8 | namibe
# Processing Record 29 of Set 8 | hay river
# Processing Record 30 of Set 8 | college
# Processing Record 31 of Set 8 | teya
# Processing Record 32 of Set 8 | ercis
# Processing Record 33 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 8 | san policarpo
# Processing Record 35 of Set 8 | camapua
# Processing Record 36 of Set 8 | lima
# Processing Record 37 of Set 8 | richards bay
# Processing Record 38 of Set 8 | talara
# Processing Record 39 of Set 8 | kalmunai
# Processing Record 40 of Set 8 | boa vista
# Processing Record 41 of Set 8 | lavrentiya
# Processing Record 42 of Set 8 | arman
# Processing Record 43 of Set 8 | bubaque
# Processing Record 44 of Set 8 | beloha
# Processing Record 45 of Set 8 | korla
# Processing Record 46 of Set 8 | touros
# Processing Record 47 of Set 8 | eberswalde
# Processing Record 48 of Set 8 | gashua
# Processing Record 49 of Set 8 | pangkalanbuun
# Processing Record 50 of Set 8 | biak
# Processing Record 1 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 2 of Set 9 | perth
# Processing Record 3 of Set 9 | eirunepe
# Processing Record 4 of Set 9 | warwick
# Processing Record 5 of Set 9 | flinders
# Processing Record 6 of Set 9 | aldergrove
# Processing Record 7 of Set 9 | naze
# Processing Record 8 of Set 9 | uyovu
# Processing Record 9 of Set 9 | mae sot
# Processing Record 10 of Set 9 | bellavista
# Processing Record 11 of Set 9 | alyangula
# Processing Record 12 of Set 9 | polunochnoye
# Processing Record 13 of Set 9 | ripiceni
# Processing Record 14 of Set 9 | mazatlan
# Processing Record 15 of Set 9 | russell
# Processing Record 16 of Set 9 | port blair
# Processing Record 17 of Set 9 | praia da vitoria
# Processing Record 18 of Set 9 | kvitok
# Processing Record 19 of Set 9 | leningradskiy
# Processing Record 20 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 9 | kayerkan
# Processing Record 22 of Set 9 | sao filipe
# Processing Record 23 of Set 9 | dubai
# Processing Record 24 of Set 9 | mareeba
# Processing Record 25 of Set 9 | tevaitoa
# Processing Record 26 of Set 9 | san andres
# Processing Record 27 of Set 9 | homer
# Processing Record 28 of Set 9 | elko
# Processing Record 29 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 30 of Set 9 | del rio
# Processing Record 31 of Set 9 | afyonkarahisar
# Processing Record 32 of Set 9 | necochea
# Processing Record 33 of Set 9 | te anau
# Processing Record 34 of Set 9 | hurricane
# Processing Record 35 of Set 9 | tagusao
# Processing Record 36 of Set 9 | zlotow
# Processing Record 37 of Set 9 | lagoa
# Processing Record 38 of Set 9 | vadso
# Processing Record 39 of Set 9 | placido de castro
# Processing Record 40 of Set 9 | ballitoville
# Processing Record 41 of Set 9 | balkanabat
# Processing Record 42 of Set 9 | sept-iles
# Processing Record 43 of Set 9 | aranos
# Processing Record 44 of Set 9 | teluk nibung
# Processing Record 45 of Set 9 | geraldton
# Processing Record 46 of Set 9 | rumia
# Processing Record 47 of Set 9 | banda aceh
# Processing Record 48 of Set 9 | alberton
# Processing Record 49 of Set 9 | itoman
# Processing Record 50 of Set 9 | baghdad
# Processing Record 1 of Set 10 | timizart
# Processing Record 2 of Set 10 | nome
# Processing Record 3 of Set 10 | poya
# Processing Record 4 of Set 10 | tarko-sale
# Processing Record 5 of Set 10 | smithers
# Processing Record 6 of Set 10 | port augusta
# Processing Record 7 of Set 10 | severnoye
# Processing Record 8 of Set 10 | shishou
# Processing Record 9 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 10 of Set 10 | suclayin
# Processing Record 11 of Set 10 | namtsy
# Processing Record 12 of Set 10 | ouro preto do oeste
# Processing Record 13 of Set 10 | plastun
# Processing Record 14 of Set 10 | wajir
# Processing Record 15 of Set 10 | alofi
# Processing Record 16 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 17 of Set 10 | morropon
# Processing Record 18 of Set 10 | tokyo
# Processing Record 19 of Set 10 | mezen
# Processing Record 20 of Set 10 | impfondo
# Processing Record 21 of Set 10 | matata
# Processing Record 22 of Set 10 | redlands
# Processing Record 23 of Set 10 | brigantine
# Processing Record 24 of Set 10 | prince george
# Processing Record 25 of Set 10 | niksar
# Processing Record 26 of Set 10 | kondopoga
# Processing Record 27 of Set 10 | inhambane
# Processing Record 28 of Set 10 | morki
# Processing Record 29 of Set 10 | chumikan
# Processing Record 30 of Set 10 | galveston
# Processing Record 31 of Set 10 | cape coast
# Processing Record 32 of Set 10 | luderitz
# Processing Record 33 of Set 10 | chardara
# Processing Record 34 of Set 10 | la ferte-bernard
# Processing Record 35 of Set 10 | pavia
# Processing Record 36 of Set 10 | honiara
# Processing Record 37 of Set 10 | mlimba
# Processing Record 38 of Set 10 | bathsheba
# Processing Record 39 of Set 10 | trat
# Processing Record 40 of Set 10 | paamiut
# Processing Record 41 of Set 10 | sibolga
# Processing Record 42 of Set 10 | moba
# Processing Record 43 of Set 10 | samarai
# Processing Record 44 of Set 10 | bulungu
# Processing Record 45 of Set 10 | athabasca
# Processing Record 46 of Set 10 | gushi
# Processing Record 47 of Set 10 | koshurnikovo
# Processing Record 48 of Set 10 | samana
# Processing Record 49 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 10 | semey
# Processing Record 1 of Set 11 | ikot ekpene
# Processing Record 2 of Set 11 | gat
# Processing Record 3 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 11 | torfyanoy
# Processing Record 5 of Set 11 | tilichiki
# Processing Record 6 of Set 11 | bantou
# Processing Record 7 of Set 11 | zvecka
# Processing Record 8 of Set 11 | wildwood
# Processing Record 9 of Set 11 | tostamaa
# City not found. Skipping...
# Processing Record 10 of Set 11 | vryburg
# Processing Record 11 of Set 11 | ostrovnoy
# Processing Record 12 of Set 11 | faya
# Processing Record 13 of Set 11 | salekhard
# Processing Record 14 of Set 11 | holbeach
# Processing Record 15 of Set 11 | olafsvik
# Processing Record 16 of Set 11 | hirara
# Processing Record 17 of Set 11 | ambunti
# Processing Record 18 of Set 11 | pizarro
# Processing Record 19 of Set 11 | lianzhou
# Processing Record 20 of Set 11 | petrokhorion
# Processing Record 21 of Set 11 | deputatskiy
# Processing Record 22 of Set 11 | zhezkazgan
# Processing Record 23 of Set 11 | lata
# Processing Record 24 of Set 11 | moose factory
# Processing Record 25 of Set 11 | port hedland
# Processing Record 26 of Set 11 | dedougou
# Processing Record 27 of Set 11 | turbat
# Processing Record 28 of Set 11 | umba
# Processing Record 29 of Set 11 | akureyri
# Processing Record 30 of Set 11 | berdigestyakh
# Processing Record 31 of Set 11 | nishihara
# Processing Record 32 of Set 11 | riyadh
# Processing Record 33 of Set 11 | juneau
# Processing Record 34 of Set 11 | kirakira
# Processing Record 35 of Set 11 | soyo
# Processing Record 36 of Set 11 | iwanai
# Processing Record 37 of Set 11 | songea
# Processing Record 38 of Set 11 | oranjestad
# Processing Record 39 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 11 | punta alta
# Processing Record 41 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 11 | haverfordwest
# Processing Record 43 of Set 11 | dolinsk
# Processing Record 44 of Set 11 | daitari
# Processing Record 45 of Set 11 | atakpame
# Processing Record 46 of Set 11 | roxana
# Processing Record 47 of Set 11 | katsuura
# Processing Record 48 of Set 11 | grand-santi
# Processing Record 49 of Set 11 | maragogi
# Processing Record 50 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 1 of Set 12 | sovetskoye
# Processing Record 2 of Set 12 | hambantota
# Processing Record 3 of Set 12 | flin flon
# Processing Record 4 of Set 12 | inta
# Processing Record 5 of Set 12 | gunnedah
# Processing Record 6 of Set 12 | barao de melgaco
# Processing Record 7 of Set 12 | sabzevar
# Processing Record 8 of Set 12 | cape canaveral
# Processing Record 9 of Set 12 | grimari
# City not found. Skipping...
# Processing Record 10 of Set 12 | khuzhir
# Processing Record 11 of Set 12 | baykit
# Processing Record 12 of Set 12 | taltal
# Processing Record 13 of Set 12 | ballina
# Processing Record 14 of Set 12 | vanimo
# Processing Record 15 of Set 12 | high level
# Processing Record 16 of Set 12 | bonavista
# Processing Record 17 of Set 12 | tura
# Processing Record 18 of Set 12 | lompoc
# Processing Record 19 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 12 | fomboni
# Processing Record 21 of Set 12 | west helena
# Processing Record 22 of Set 12 | tateyama
# Processing Record 23 of Set 12 | seoul
# Processing Record 24 of Set 12 | vila velha
# Processing Record 25 of Set 12 | kacarevo
# Processing Record 26 of Set 12 | pimenta bueno
# Processing Record 27 of Set 12 | okato
# Processing Record 28 of Set 12 | lubao
# Processing Record 29 of Set 12 | tucuman
# Processing Record 30 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 31 of Set 12 | ambilobe
# Processing Record 32 of Set 12 | sidi ali
# Processing Record 33 of Set 12 | constitucion
# Processing Record 34 of Set 12 | baruun-urt
# Processing Record 35 of Set 12 | copiapo
# Processing Record 36 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 12 | yemelyanovo
# Processing Record 38 of Set 12 | abalak
# Processing Record 39 of Set 12 | ekangala
# Processing Record 40 of Set 12 | noumea
# Processing Record 41 of Set 12 | wigan
# Processing Record 42 of Set 12 | papara
# Processing Record 43 of Set 12 | ludza
# Processing Record 44 of Set 12 | gilazi
# City not found. Skipping...
# Processing Record 45 of Set 12 | liwale
# Processing Record 46 of Set 12 | kabinda
# Processing Record 47 of Set 12 | chicama
# Processing Record 48 of Set 12 | dhule
# Processing Record 49 of Set 12 | duki
# Processing Record 50 of Set 12 | latung
# Processing Record 1 of Set 13 | ginda
# Processing Record 2 of Set 13 | kozmodemyansk
# Processing Record 3 of Set 13 | kuvshinovo
# Processing Record 4 of Set 13 | sandwick
# Processing Record 5 of Set 13 | dashitou
# Processing Record 6 of Set 13 | hopfgarten
# Processing Record 7 of Set 13 | maputo
# Processing Record 8 of Set 13 | adrar
# Processing Record 9 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 13 | khasan
# Processing Record 11 of Set 13 | dunmore east
# Processing Record 12 of Set 13 | solnechnyy
# Processing Record 13 of Set 13 | desaguadero
# Processing Record 14 of Set 13 | katha
# City not found. Skipping...
# Processing Record 15 of Set 13 | tuy hoa
# Processing Record 16 of Set 13 | mujiayingzi
# Processing Record 17 of Set 13 | nantucket
# Processing Record 18 of Set 13 | dinklage
# Processing Record 19 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 13 | wanning
# Processing Record 21 of Set 13 | road town
# Processing Record 22 of Set 13 | swan hill
# Processing Record 23 of Set 13 | sharjah
# Processing Record 24 of Set 13 | rancho veloz
# Processing Record 25 of Set 13 | antalaha
# Processing Record 26 of Set 13 | wattegama
# Processing Record 27 of Set 13 | iskilip
# Processing Record 28 of Set 13 | yablonovo
# Processing Record 29 of Set 13 | mumbwa
# Processing Record 30 of Set 13 | dingle
# Processing Record 31 of Set 13 | naryan-mar
# Processing Record 32 of Set 13 | tshane
# Processing Record 33 of Set 13 | sorgun
# Processing Record 34 of Set 13 | atambua
# Processing Record 35 of Set 13 | wladyslawowo
# Processing Record 36 of Set 13 | providencia
# Processing Record 37 of Set 13 | chubbuck
# Processing Record 38 of Set 13 | fortuna
# Processing Record 39 of Set 13 | mendi
# Processing Record 40 of Set 13 | henties bay
# Processing Record 41 of Set 13 | blind river
# Processing Record 42 of Set 13 | san juan de los morros
# Processing Record 43 of Set 13 | pochutla
# Processing Record 44 of Set 13 | nhulunbuy
# Processing Record 45 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 13 | beisfjord
# Processing Record 47 of Set 13 | pingyin
# Processing Record 48 of Set 13 | santa rosa
# Processing Record 49 of Set 13 | stonewall
# Processing Record 50 of Set 13 | marsa matruh
# Processing Record 1 of Set 14 | jacareacanga
# Processing Record 2 of Set 14 | halifax
# Processing Record 3 of Set 14 | akom
# Processing Record 4 of Set 14 | sao borja
# Processing Record 5 of Set 14 | silver city
# Processing Record 6 of Set 14 | lamballe
# Processing Record 7 of Set 14 | goderich
# Processing Record 8 of Set 14 | masuguru
# Processing Record 9 of Set 14 | yeppoon
# Processing Record 10 of Set 14 | santiago del estero
# Processing Record 11 of Set 14 | maldonado
# Processing Record 12 of Set 14 | virginia beach
# Processing Record 13 of Set 14 | houma
# Processing Record 14 of Set 14 | feldkirchen-westerham
# Processing Record 15 of Set 14 | ferme-neuve
# Processing Record 16 of Set 14 | maniwaki
# Processing Record 17 of Set 14 | santa catalina
# Processing Record 18 of Set 14 | sobolevo
# Processing Record 19 of Set 14 | shache
# Processing Record 20 of Set 14 | paracuru
# Processing Record 21 of Set 14 | bangassou
# Processing Record 22 of Set 14 | deogarh
# Processing Record 23 of Set 14 | candolim
# Processing Record 24 of Set 14 | luis correia
# Processing Record 25 of Set 14 | vao
# Processing Record 26 of Set 14 | imbituba
# Processing Record 27 of Set 14 | swift current
# Processing Record 28 of Set 14 | belturbet
# Processing Record 29 of Set 14 | nyurba
# Processing Record 30 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 14 | urumqi
# Processing Record 32 of Set 14 | bellevue
# Processing Record 33 of Set 14 | leh
# Processing Record 34 of Set 14 | palana
# Processing Record 35 of Set 14 | suhbaatar
# Processing Record 36 of Set 14 | ust-nera
# Processing Record 37 of Set 14 | shimoda
# Processing Record 38 of Set 14 | kaitangata
# Processing Record 39 of Set 14 | ambon
# Processing Record 40 of Set 14 | verkhnyaya inta
# Processing Record 41 of Set 14 | sirnak
# Processing Record 42 of Set 14 | fukue
# Processing Record 43 of Set 14 | bagn
# Processing Record 44 of Set 14 | high rock
# Processing Record 45 of Set 14 | alekseyevskoye
# Processing Record 46 of Set 14 | gamba
# Processing Record 47 of Set 14 | northam
# Processing Record 48 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 14 | tezu
# Processing Record 50 of Set 14 | sangar
# Processing Record 1 of Set 15 | sungaipenuh
# Processing Record 2 of Set 15 | quelimane
# Processing Record 3 of Set 15 | cap malheureux
# Processing Record 4 of Set 15 | satellite beach
# Processing Record 5 of Set 15 | cacoal
# Processing Record 6 of Set 15 | bilibino
# Processing Record 7 of Set 15 | calvia
# Processing Record 8 of Set 15 | saint-augustin
# Processing Record 9 of Set 15 | ekibastuz
# Processing Record 10 of Set 15 | dharchula
# Processing Record 11 of Set 15 | wana
# Processing Record 12 of Set 15 | sydney mines
# Processing Record 13 of Set 15 | suao
# City not found. Skipping...
# Processing Record 14 of Set 15 | omsukchan
# Processing Record 15 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 15 | bac can
# City not found. Skipping...
# Processing Record 17 of Set 15 | honningsvag
# Processing Record 18 of Set 15 | gua musang
# Processing Record 19 of Set 15 | gumdag
# Processing Record 20 of Set 15 | sinnamary
# Processing Record 21 of Set 15 | rocha
# Processing Record 22 of Set 15 | aripuana
# Processing Record 23 of Set 15 | eyl
# Processing Record 24 of Set 15 | salinas
# Processing Record 25 of Set 15 | paita
# Processing Record 26 of Set 15 | orumiyeh
# Processing Record 27 of Set 15 | mkushi
# Processing Record 28 of Set 15 | kirkenes
# Processing Record 29 of Set 15 | mahibadhoo
# Processing Record 30 of Set 15 | aksu
# Processing Record 31 of Set 15 | aykhal
# Processing Record 32 of Set 15 | knysna
# Processing Record 33 of Set 15 | lampazos de naranjo
# Processing Record 34 of Set 15 | walvis bay
# Processing Record 35 of Set 15 | adre
# Processing Record 36 of Set 15 | narsaq
# Processing Record 37 of Set 15 | neu wulmstorf
# Processing Record 38 of Set 15 | srandakan
# Processing Record 39 of Set 15 | mizdah
# Processing Record 40 of Set 15 | half moon bay
# Processing Record 41 of Set 15 | zabol
# Processing Record 42 of Set 15 | umm kaddadah
# Processing Record 43 of Set 15 | mvuma
# Processing Record 44 of Set 15 | kemin
# Processing Record 45 of Set 15 | kittery
# Processing Record 46 of Set 15 | key west
# Processing Record 47 of Set 15 | kushima
# Processing Record 48 of Set 15 | granada
# Processing Record 49 of Set 15 | lucapa
# Processing Record 50 of Set 15 | salinopolis
# Processing Record 1 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 16 | manicore
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Rikitea -23.1203 -134.9692     74.79        70           4       17.90
# 1   Chokurdakh  70.6333  147.9167    -15.77        94         100       12.39
# 2       Assiut  27.1810   31.1837     62.78        55           1        5.59
# 3     Lorengau  -2.0226  147.2712     80.67        80         100        6.08
# 4    Yuancheng  36.6520  107.7896     21.20        32           0        6.33
# 5  Port Alfred -33.5906   26.8910     73.89        89         100        5.75
# 6      Qaanaaq  77.4840  -69.3632      2.05        94         100        4.94
# 7       Burnie -41.0667  145.9167     52.95        68          79       12.55
# 8        Kapaa  22.0752 -159.3190     80.92        72           0       18.41
# 9      Chifeng  42.2683  118.9636      3.34        37           0        8.46
#
#   Country Current Description
# 0      PF           clear sky
# 1      RU     overcast clouds
# 2      EG           clear sky
# 3      PG     overcast clouds
# 4      CN           clear sky
# 5      ZA     overcast clouds
# 6      GL     overcast clouds
# 7      AU       broken clouds
# 8      US           clear sky
# 9      CN           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rikitea      PF -23.1203 -134.9692     74.79        70           4
# 1   Chokurdakh      RU  70.6333  147.9167    -15.77        94         100
# 2       Assiut      EG  27.1810   31.1837     62.78        55           1
# 3     Lorengau      PG  -2.0226  147.2712     80.67        80         100
# 4    Yuancheng      CN  36.6520  107.7896     21.20        32           0
# 5  Port Alfred      ZA -33.5906   26.8910     73.89        89         100
# 6      Qaanaaq      GL  77.4840  -69.3632      2.05        94         100
# 7       Burnie      AU -41.0667  145.9167     52.95        68          79
# 8        Kapaa      US  22.0752 -159.3190     80.92        72           0
# 9      Chifeng      CN  42.2683  118.9636      3.34        37           0
#
#    Wind Speed Current Description
# 0       17.90           clear sky
# 1       12.39     overcast clouds
# 2        5.59           clear sky
# 3        6.08     overcast clouds
# 4        6.33           clear sky
# 5        5.75     overcast clouds
# 6        4.94     overcast clouds
# 7       12.55       broken clouds
# 8       18.41           clear sky
# 9        8.46           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
